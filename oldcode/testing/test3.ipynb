# %%
import pandas as pd

df = pd.read_csv('../database/Siembras.csv')

dfBagre = df.loc[
    (df['Ciudad'] == 'El Bagre') & (df['Arboles'] > 60) 
]

dfBagre
# Out:
#      Ticket                                       Nombre comun  \
# 724    1378                                   Almendron, Samán
# 725    1372                                   Almendron, Samán
# 726    1633                                   Almendron, Samán
# 728    1370                              Guayacan de Manizales
# 729    1373                                   Almendron, Samán
# ..      ...                                                ...
# 817    1634                                   Almendron, Samán
# 818    1637                                   Almendron, Samán
# 820    1643                                   Almendron, Samán
# 822    1701  Cedro, Piñón de Oreja, Suribio, Caracolí, Alga...
# 823    1874  Guayacán Amarillo, Cedro, orejero, Suribio, Ca...
#
#                       Fecha                                    evento  \
# 724  11/18/2020 12:00:00 AM  siembra Voluntaria Mineros Aluvial S.A.S
# ...
