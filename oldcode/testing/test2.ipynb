# %%
import pandas as pd

df = pd.read_csv('../database/Siembras.csv')

dfSantaFe = df.loc[
    (df['Ciudad'] == 'Santa Fe de Antioquia') & ((df['Vereda'] == 'Paso Real') | (df['Vereda'] == 'Tonusco Arriba'))
     ]

dfSantaFe
# Out:
#      Ticket                                   Nombre comun  \
# 228     227                                          Ébano
# 229    1135                    Cedro, Piñón de Oreja, Noro
# 230    1014   Guayacan Amarillo, Cedro Amarillo, Algarrobo
# 231     231                                 Suribio, Ebano
# 232     243  Ébano (Diospyros), Suribio (Zygia Longifolia)
# 233     368    Suribio (Zygia Longifolia), Ebenopsis ebano
# 234     225                                          Ébano
# 235    1663                     Habano, Diomato, Algarrobo
# 239    1025     Guayacán Amarillo, Guayacan Rosado, Guadua
#
#                       Fecha              evento                 Ciudad  \
# 228  11/07/2020 12:00:00 AM   Cada uno un árbol  Santa Fe de Antioquia
# 229  05/28/2021 12:00:00 AM           Sembratón  Santa Fe de Antioquia
# 230  11/26/2020 12:00:00 AM           Sembratón  Santa Fe de Antioquia
# 231  11/07/2020 12:00:00 AM   Cada uno un árbol  Santa Fe de Antioquia
# ...
